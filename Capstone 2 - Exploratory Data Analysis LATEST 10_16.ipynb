# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import datetime as dt

# %%
#read in dataframes for total deaths per state, cumulative deaths per day per state, demographic 
#and macroeconomic indicators
df= pd.read_csv('total_deaths_perstate.csv',index_col=[0])
df2 = pd.read_csv('all_deaths_total.csv', index_col=[0]) 
macro_df = pd.read_csv('macro_df.csv')

# %%
print(len(macro_df['State']))
print(df.dtypes)
print(df.shape)
print(df.isna().sum().sum())
# Out:
# 50
# Date      object
# State     object
# Fips       int64
# Cases      int64
# Deaths     int64
# dtype: object
# (50, 5)
# 0

# %%
#plot deaths per state
import matplotlib.ticker as ticker

df_desc = df.sort_values(by=['Deaths'],ascending=True)
fig, ax = plt.subplots(figsize=(15, 8))
ax.barh(df_desc['State'], df_desc['Deaths'])
ax.set_title('COVID-19 Deaths Per State',fontsize=25,fontname='Times New Roman')
ax.set_xlabel('Deaths',fontsize=20,fontname='Times New Roman')
ax.set_ylabel('State',fontsize=20,fontname='Times New Roman')

for i, (value, name) in enumerate(zip(df_desc['Deaths'], df_desc['State'])):
    ax.text(value, i,     value,           ha='left')   
# Add year right middle portion of canvas
ax.text(1, 0.4, '2020-Present', transform=ax.transAxes, size=36, ha='right',fontname='Times New Roman')

ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
ax.xaxis.set_ticks_position('top')
ax.tick_params(axis='x', colors='#777777', labelsize=12)
ax.margins(0, 0.01)
ax.grid(which='major', axis='x', linestyle='-')

# %% [markdown]
# Do the overall COVID-19 deaths alone indicate that California, Texas and Florida were the most affected?

# %% [markdown]
# Specficially investigate top 5 highest affected states.

# %%
#import deaths per month for all states 
all_months = pd.read_csv('all_deaths_month.csv',index_col=[0])

# %%
#plots deaths per month for California 
x = all_months[all_months['state']=='California']['Month_year']
y = all_months[all_months['state']=='California']['deaths_permonth']

plt.plot(x,y)
plt.xticks(rotation=90)
plt.xlabel('Month and Year',fontname='Times New Roman')
plt.ylabel('Deaths',fontname='Times New Roman')
plt.title('COVID-19 Deaths in California from 2020-2022',fontname='Times New Roman')

plt.show()

# %%
#plots deaths per month for Texas 
x = all_months[all_months['state']=='Texas']['Month_year']
y = all_months[all_months['state']=='Texas']['deaths_permonth']

plt.plot(x,y)
plt.xticks(rotation=90)
plt.xlabel('Month and Year',fontname='Times New Roman')
plt.ylabel('Deaths',fontname='Times New Roman')
plt.title('COVID-19 Deaths in Texas from 2020-2022',fontname='Times New Roman')

plt.show()

# %%
#plots deaths per month for Florida
x = all_months[all_months['state']=='Florida']['Month_year']
y = all_months[all_months['state']=='Florida']['deaths_permonth']

plt.plot(x,y)
plt.xticks(rotation=90)
plt.xlabel('Month and Year',fontname='Times New Roman')
plt.ylabel('Deaths',fontname='Times New Roman')
plt.title('COVID-19 Deaths in Florida from 2020-2022',fontname='Times New Roman')

plt.show()

# %%
#plots deaths per month for New York
x = all_months[all_months['state']=='New York']['Month_year']
y = all_months[all_months['state']=='New York']['deaths_permonth']

plt.plot(x,y)
plt.xticks(rotation=90)
plt.xlabel('Month and Year',fontname='Times New Roman')
plt.ylabel('Deaths',fontname='Times New Roman')
plt.title('COVID-19 Deaths in New York from 2020-2022',fontname='Times New Roman')

plt.show()

# %%
#plots deaths per month for Pennsylvania
x = all_months[all_months['state']=='Pennsylvania']['Month_year']
y = all_months[all_months['state']=='Pennsylvania']['deaths_permonth']

plt.plot(x,y)
plt.xticks(rotation=90)
plt.xlabel('Month and Year',fontname='Times New Roman')
plt.ylabel('Deaths',fontname='Times New Roman')
plt.title('COVID-19 Deaths in Pennsylvania from 2020-2022',fontname='Times New Roman')

plt.show()

# %% [markdown]
# Which of the top 5 states with the most COVID-19 deaths reflects the same trends as the overall COVID-19 deaths? It seems like California is most similar. Is California the most representative of the United States as a whole when it comes to the features we are investigating?

# %%
#plot deaths versus air traffic
air_traffic = pd.read_csv('air_traffic.csv', index_col=[0]) 
air_traffic = air_traffic[['domestic','Month_year']]

# %%
air_vs_deaths = pd.merge(air_traffic, all_months, on='Month_year',how='inner')
air_vs_deaths = air_vs_deaths[~(air_vs_deaths['Month_year'] > '2022-06')]
air_vs_deaths.head()
# Out:
#    domestic  Month_year       state  deaths_permonth
# 0  61638893  2020-01-01     Arizona              0.0
# 1  61638893  2020-01-01  California              0.0
# 2  61638893  2020-01-01    Illinois              0.0
# 3  61638893  2020-01-01  Washington              0.0
# 4  59879630  2020-02-01     Arizona              0.0

# %%
air_vs_deaths2 = air_vs_deaths.groupby(['Month_year','domestic'])['deaths_permonth'].sum().reset_index()
print(air_vs_deaths2.head())
print(air_vs_deaths2.info())
# Out:
#    Month_year  domestic  deaths_permonth
# 0  2020-01-01  61638893              0.0
# 1  2020-02-01  59879630              1.0
# 2  2020-03-01  34420555           4283.0
# 3  2020-04-01   2879712          58527.0
# 4  2020-05-01   7861491          40951.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Month_year       29 non-null     object
#  1   domestic         29 non-null     int64
#  2   deaths_permonth  29 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 824.0+ bytes
# None

# %% [markdown]
# The airlines were one of the biggest things to shut down during COVID-19. How does the number of domestic passengers relate to the number of COVID-19 deaths in the United States as a whole?

# %%
#create variables to plot
deaths = air_vs_deaths2['deaths_permonth']
dom_flights = air_vs_deaths2['domestic']
month = air_vs_deaths2['Month_year']

#check variables
#print(deaths)
#print(dom_flights)
#print(month)

# %%
fig, ax = plt.subplots()

#plot timeline on the x axis and number of deaths on y
ax.plot(month, deaths, color='pink')
ax.tick_params(axis='y', labelcolor='black')
plt.xticks(rotation=90)

#add new axes
ax2 = ax.twinx()

# plot domestic flight traffic and set scale to logarithmic to scale with deaths 
ax2.plot(dom_flights, color='purple')
ax2.set_yscale('log')
ax2.tick_params(axis='y', labelcolor='black')

ax.set_title('COVID-19 Deaths All States vs. Domestic Flight Passengers 2020-2022',fontname='Times New Roman')
ax.set_xlabel('Date',fontname='Times New Roman')
ax.set_ylabel('Deaths',fontname='Times New Roman')
ax2.set_ylabel('Number of Passengers',fontname='Times New Roman')

plt.show()

# %%
#possible additional deliverable?
#plot matplotlib timeline of mask mandates and major holidays versus covid deaths
#https://cds.climate.copernicus.eu/toolbox/doc/how-to/3_how_to_plot_time_series/3_how_to_plot_time_series.html

# %%
#find month/year with peak deaths
air_vs_deaths2.iloc[air_vs_deaths2['deaths_permonth'].idxmax()]
# Out:
# Month_year         2021-01-01
# domestic             24305908
# deaths_permonth       94788.0
# Name: 12, dtype: object

# %%
#find top 5 month/year with peak deaths 
air_vs_deaths.sort_values('deaths_permonth',ascending=False)
#top 3 deaths by month were in the beginning of 2021... what events could have led to this?
# Out:
#       domestic  Month_year          state  deaths_permonth
# 95     2879712  2020-04-01       New York          21687.0
# 518   24305908  2021-01-01     California          14963.0
# 568   24483505  2021-02-01     California          11285.0
# 922   53903524  2021-09-01        Florida          10448.0
# 556   24305908  2021-01-01          Texas           9087.0
# ...        ...         ...            ...              ...
# 54    34420555  2020-03-01   South Dakota              0.0
# 358   23854772  2020-09-01        Vermont              0.0
# 408   28027209  2020-10-01        Vermont              0.0
# 1     61638893  2020-01-01     California              0.0
# 1234  64604568  2022-03-01  Massachusetts          -3319.0
#
# [1364 rows x 4 columns]

# %%
#plot correlation between columns in macro info dataframe
plt.figure(figsize=(12,10))
print('Correlation between various features')
p=sns.heatmap(macro_df.corr(), annot=True,cmap ='PiYG',linewidths=4)
# Out:
# Correlation between various features
# C:\Users\laure\AppData\Local\Temp\ipykernel_6664\2737270796.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   p=sns.heatmap(macro_df.corr(), annot=True,cmap ='PiYG',linewidths=4)

# %%
#correlation between deaths and other columns
#The Result of the corr() method is a table with a lot of numbers that represents how well the relationship is between two columns.
#The number varies from -1 to 1.
#1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.
#0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
#-0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
#0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.

deaths_corr = macro_df[macro_df.columns[1:]].corr()['Deaths'][:]

print(deaths_corr)
# Out:
# Cases                                                 0.972847
# Deaths                                                1.000000
# Percent African American                              0.284419
# Percent American Indian And Alaska Native            -0.233846
# Percent Asian                                         0.152693
# Percent Native Hawaiian And Other Pacific Islander   -0.141103
# Percent Two Or More Races                            -0.138449
# Percent Hispanic Or Latino                            0.509375
# Percent White Not Hispanic Or Latino                 -0.456957
# Median Household Income                               0.017543
# Percent Persons Below Poverty Level                   0.160476
# Name: Deaths, dtype: float64
# C:\Users\laure\AppData\Local\Temp\ipykernel_6664\636206814.py:9: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   deaths_corr = macro_df[macro_df.columns[1:]].corr()['Deaths'][:]

# %%
#correlogram of different demographic and macroeconomic indicators vs total deaths
sns.pairplot(macro_df[['Deaths','Percent Hispanic Or Latino','Percent White Not Hispanic Or Latino',
                'Percent African American','Percent American Indian And Alaska Native']],
             height=2.5)
sns.set(font_scale=1)

# %%
state_pop_2021 = pd.read_csv('state_pop_2021.csv', index_col=[0]) 
state_deaths_2021 = pd.read_csv('state_deaths_2021.csv', index_col=[0])
deaths_pop_2021 = pd.read_csv('deaths_pop_2021.csv',index_col=[0])
print(state_deaths_2021.head())
print(state_pop_2021.head())
print(deaths_pop_2021.head())
# Out:
#             state  deaths        date
# 36854     Alabama   11583  2021-12-31
# 36855      Alaska     756  2021-12-31
# 36857     Arizona   15214  2021-12-31
# 36858    Arkansas    5437  2021-12-31
# 36859  California   50473  2021-12-31
#         state  population  % population affected
# 4     Alabama     5039877               0.002298
# 5      Alaska      732673               0.001032
# 6     Arizona     7276316               0.002091
# 7    Arkansas     3025891               0.001797
# 8  California    39237836               0.001286
#         state  deaths        date  population
# 0     Alabama   11583  2021-12-31     5039877
# 1      Alaska     756  2021-12-31      732673
# 2     Arizona   15214  2021-12-31     7276316
# 3    Arkansas    5437  2021-12-31     3025891
# 4  California   50473  2021-12-31    39237836

# %%
#plot state deaths versus state populations
x = deaths_pop_2021['deaths']
y = deaths_pop_2021['population']
c = state_pop_2021['% population affected']

fig, ax = plt.subplots()
scatter = ax.scatter(x, y, c=c)
ax.set_xlabel('Deaths',fontsize=20,fontname='Times New Roman')
ax.set_ylabel('Population',fontsize=20,fontname='Times New Roman')
ax.set_title('COVID-19 Deaths vs. State Population',fontsize=25, fontname='Times New Roman')
annotations=deaths_pop_2021['state'].tolist()
for i, label in enumerate(annotations):
    plt.annotate(label, (x[i], y[i]), fontsize=15,fontname='Times New Roman')

legend1 = ax.legend(*scatter.legend_elements(),
                    loc='lower right', title='Percent Population Affected')
ax.add_artist(legend1)

fig.set_size_inches(18.5, 10.5)

plt.show()

# %%
#create merged data frame so can annotate state name onto graph
merged=pd.merge(deaths_pop_2021, state_pop_2021, on='state', how='outer')
#merged.head()

# %%
x = merged['deaths']
y = merged['% population affected']
c = macro_df['Median Household Income']

fig, ax = plt.subplots()
scatter = ax.scatter(x, y,c=c)
ax.set_xlabel('Deaths',fontsize=20,fontname='Times New Roman')
ax.set_ylabel('% Population Affected',fontsize=20,fontname='Times New Roman')
ax.set_title('Percent Population Affected vs. Deaths',fontsize=25, fontname='Times New Roman')

annotations=merged['state'].tolist()
for i, label in enumerate(annotations):
    plt.annotate(label, (x[i], y[i]),fontsize=15,fontname='Times New Roman')

legend1 = ax.legend(*scatter.legend_elements(),
                    loc='upper right', title='Median Household Income')
ax.add_artist(legend1)
fig.set_size_inches(18.5, 10.5)

plt.show()

# %%
#import health indicators dataframe
state_health_df = pd.read_csv('state_health_df_2021.csv', index_col=[0])
state_health_df['Measure Name'].unique().tolist()
# Out:
# ['Access to Care - Annual',
#  'Adverse Childhood Experiences',
#  'Air and Water Quality - Annual',
#  'Air Pollution',
#  'All Determinants - Annual',
#  'Arthritis',
#  'Arthritis - $25-$49,999',
#  'Arthritis - $50-$74,999',
#  'Arthritis - $75,000 or More',
#  'Arthritis - Ages 18-44',
#  'Arthritis - Ages 45-64',
#  'Arthritis - Ages 65+',
#  'Arthritis - American Indian/Alaska Native',
#  'Arthritis - Asian',
#  'Arthritis - Black',
#  'Arthritis - College Grad',
#  'Arthritis - Female',
#  'Arthritis - Hawaiian/Pacific Islander',
#  'Arthritis - High School/GED',
#  'Arthritis - Hispanic',
#  'Arthritis - Less Than $25,000',
#  'Arthritis - Less Than High School',
#  'Arthritis - Male',
#  'Arthritis - Multiracial',
#  'Arthritis - Other Race',
#  'Arthritis - Some Post-High School',
#  'Arthritis - White',
#  'Asthma',
#  'Asthma - $25-$49,999',
#  'Asthma - $50-$74,999',
#  'Asthma - $75,000 or More',
#  'Asthma - Ages 18-44',
#  'Asthma - Ages 45-64',
#  'Asthma - Ages 65+',
#  'Asthma - American Indian/Alaska Native',
#  'Asthma - Asian',
#  'Asthma - Black',
#  'Asthma - College Grad',
#  'Asthma - Female',
#  'Asthma - Hawaiian/Pacific Islander',
#  'Asthma - High School/GED',
#  'Asthma - Hispanic',
#  'Asthma - Less Than $25,000',
#  'Asthma - Less Than High School',
#  'Asthma - Male',
#  'Asthma - Multiracial',
#  'Asthma - Other Race',
#  'Asthma - Some Post-High School',
#  'Asthma - White',
#  'Avoided Care Due to Cost',
#  'Avoided Care Due to Cost - $25-$49,999',
#  'Avoided Care Due to Cost - $50-$74,999',
#  'Avoided Care Due to Cost - $75,000 or More',
#  'Avoided Care Due to Cost - Ages 18-44',
#  'Avoided Care Due to Cost - Ages 45-64',
#  'Avoided Care Due to Cost - Ages 65+',
#  'Avoided Care Due to Cost - American Indian/Alaska Native',
#  'Avoided Care Due to Cost - Asian',
#  'Avoided Care Due to Cost - Black',
#  'Avoided Care Due to Cost - College Grad',
#  'Avoided Care Due to Cost - Female',
#  'Avoided Care Due to Cost - Hawaiian/Pacific Islander',
#  'Avoided Care Due to Cost - High School/GED',
#  'Avoided Care Due to Cost - Hispanic',
#  'Avoided Care Due to Cost - Less Than $25,000',
#  'Avoided Care Due to Cost - Less Than High School',
#  'Avoided Care Due to Cost - Male',
#  'Avoided Care Due to Cost - Multiracial',
#  'Avoided Care Due to Cost - Other Race',
#  'Avoided Care Due to Cost - Some Post-High School',
#  'Avoided Care Due to Cost - White',
#  'Behavioral Health - Annual',
#  'Behaviors',
#  'Binge Drinking',
#  'Cancer',
#  'Cancer - $25-$49,999',
#  'Cancer - $50-$74,999',
#  'Cancer - $75,000 or More',
#  'Cancer - Ages 18-44',
#  'Cancer - Ages 45-64',
#  'Cancer - Ages 65+',
#  'Cancer - American Indian/Alaska Native',
#  'Cancer - Asian',
#  'Cancer - Black',
#  'Cancer - College Grad',
#  'Cancer - Female',
#  'Cancer - Hawaiian/Pacific Islander',
#  'Cancer - High School/GED',
#  'Cancer - Hispanic',
#  'Cancer - Less Than $25,000',
#  'Cancer - Less Than High School',
#  'Cancer - Male',
#  'Cancer - Multiracial',
#  'Cancer - Other Race',
#  'Cancer - Some Post-High School',
#  'Cancer - White',
#  'Cannabis Use',
#  'Cardiovascular Diseases',
#  'Cardiovascular Diseases - $25-$49,999',
#  'Cardiovascular Diseases - $50-$74,999',
#  'Cardiovascular Diseases - $75,000 or More',
#  'Cardiovascular Diseases - Ages 18-44',
#  'Cardiovascular Diseases - Ages 45-64',
#  'Cardiovascular Diseases - Ages 65+',
#  'Cardiovascular Diseases - American Indian/Alaska Native',
#  'Cardiovascular Diseases - Asian',
#  'Cardiovascular Diseases - Black',
#  'Cardiovascular Diseases - College Grad',
#  'Cardiovascular Diseases - Female',
#  'Cardiovascular Diseases - Hawaiian/Pacific Islander',
#  'Cardiovascular Diseases - High School/GED',
#  'Cardiovascular Diseases - Hispanic',
#  'Cardiovascular Diseases - Less Than $25,000',
#  'Cardiovascular Diseases - Less Than High School',
#  'Cardiovascular Diseases - Male',
#  'Cardiovascular Diseases - Multiracial',
#  'Cardiovascular Diseases - Other Race',
#  'Cardiovascular Diseases - Some Post-High School',
#  'Cardiovascular Diseases - White',
#  'Childhood Immunizations',
#  'Chlamydia',
#  'Chlamydia - American Indian/Alaska Native',
#  'Chlamydia - Asian',
#  'Chlamydia - Black',
#  'Chlamydia - Female',
#  'Chlamydia - Hawaiian/Pacific Islander',
#  'Chlamydia - Hispanic/Latino',
#  'Chlamydia - Male',
#  'Chlamydia - Multiracial',
#  'Chlamydia - White',
#  'Chronic Kidney Disease',
#  'Chronic Kidney Disease - $25-$49,999',
#  'Chronic Kidney Disease - $50-$74,999',
#  'Chronic Kidney Disease - $75,000 or More',
#  'Chronic Kidney Disease - Ages 18-44',
#  'Chronic Kidney Disease - Ages 45-64',
#  'Chronic Kidney Disease - Ages 65+',
#  'Chronic Kidney Disease - American Indian/Alaska Native',
#  'Chronic Kidney Disease - Asian',
#  'Chronic Kidney Disease - Black',
#  'Chronic Kidney Disease - College Grad',
#  'Chronic Kidney Disease - Female',
#  'Chronic Kidney Disease - Hawaiian/Pacific Islander',
#  'Chronic Kidney Disease - High School/GED',
#  'Chronic Kidney Disease - Hispanic',
#  'Chronic Kidney Disease - Less Than $25,000',
#  'Chronic Kidney Disease - Less Than High School',
#  'Chronic Kidney Disease - Male',
#  'Chronic Kidney Disease - Multiracial',
#  'Chronic Kidney Disease - Other Race',
#  'Chronic Kidney Disease - Some Post-High School',
#  'Chronic Kidney Disease - White',
#  'Chronic Obstructive Pulmonary Disease',
#  'Chronic Obstructive Pulmonary Disease - $25-$49,999',
#  'Chronic Obstructive Pulmonary Disease - $50-$74,999',
#  'Chronic Obstructive Pulmonary Disease - $75,000 or More',
#  'Chronic Obstructive Pulmonary Disease - Ages 18-44',
#  'Chronic Obstructive Pulmonary Disease - Ages 45-64',
#  'Chronic Obstructive Pulmonary Disease - Ages 65+',
#  'Chronic Obstructive Pulmonary Disease - American Indian/Alaska Native',
#  'Chronic Obstructive Pulmonary Disease - Asian',
#  'Chronic Obstructive Pulmonary Disease - Black',
#  'Chronic Obstructive Pulmonary Disease - College Grad',
#  'Chronic Obstructive Pulmonary Disease - Female',
#  'Chronic Obstructive Pulmonary Disease - Hawaiian/Pacific Islander',
#  'Chronic Obstructive Pulmonary Disease - High School/GED',
#  'Chronic Obstructive Pulmonary Disease - Hispanic',
#  'Chronic Obstructive Pulmonary Disease - Less Than $25,000',
#  'Chronic Obstructive Pulmonary Disease - Less Than High School',
#  'Chronic Obstructive Pulmonary Disease - Male',
#  'Chronic Obstructive Pulmonary Disease - Multiracial',
#  'Chronic Obstructive Pulmonary Disease - Other Race',
#  'Chronic Obstructive Pulmonary Disease - Some Post-High School',
#  'Chronic Obstructive Pulmonary Disease - White',
#  'Climate Change Policies',
#  'Clinical Care',
#  'Colorectal Cancer Screening',
#  'Colorectal Cancer Screening - $25-$49,999',
#  'Colorectal Cancer Screening - $50-$74,999',
#  'Colorectal Cancer Screening - $75,000 or More',
#  'Colorectal Cancer Screening - American Indian/Alaska Native',
#  'Colorectal Cancer Screening - Asian',
#  'Colorectal Cancer Screening - Black',
#  'Colorectal Cancer Screening - College Grad',
#  'Colorectal Cancer Screening - Female',
#  'Colorectal Cancer Screening - Hawaiian/Pacific Islander',
#  'Colorectal Cancer Screening - High School/GED',
#  'Colorectal Cancer Screening - Hispanic',
#  'Colorectal Cancer Screening - Less Than $25,000',
#  'Colorectal Cancer Screening - Less Than High School',
#  'Colorectal Cancer Screening - Male',
#  'Colorectal Cancer Screening - Multiracial',
#  'Colorectal Cancer Screening - Other Race',
#  'Colorectal Cancer Screening - Some Post-High School',
#  'Colorectal Cancer Screening - White',
#  'Community and Family Safety - Annual',
#  'Crowded Housing',
#  'Crowded Housing - Black',
#  'Crowded Housing - Hispanic',
#  'Crowded Housing - White',
#  'Dedicated HC Provider - $25-$49,999',
#  'Dedicated HC Provider - $50-$74,999',
#  'Dedicated HC Provider - $75,000 or More',
#  'Dedicated HC Provider - 18-44',
#  'Dedicated HC Provider - 45-64',
#  'Dedicated HC Provider - 65+',
#  'Dedicated HC Provider - American Indian/Alaska Native',
#  'Dedicated HC Provider - Asian',
#  'Dedicated HC Provider - Black',
#  'Dedicated HC Provider - College Grad',
#  'Dedicated HC Provider - Female',
#  'Dedicated HC Provider - Hawaiian/Pacific Islander',
#  'Dedicated HC Provider - High School/GED',
#  'Dedicated HC Provider - Hispanic',
#  'Dedicated HC Provider - Less Than $25,000',
#  'Dedicated HC Provider - Less Than High School',
#  'Dedicated HC Provider - Male',
#  'Dedicated HC Provider - Multiracial',
#  'Dedicated HC Provider - Other Race',
#  'Dedicated HC Provider - Some Post-High School',
#  'Dedicated HC Provider - White',
#  'Dedicated Health Care Provider',
#  'Dental Care Providers',
#  'Dental Visit',
#  'Dental Visit - $25-$49,999',
#  'Dental Visit - $50-$74,999',
#  'Dental Visit - $75,000 or More',
#  'Dental Visit - Ages 18-44',
#  'Dental Visit - Ages 45-64',
#  'Dental Visit - Ages 65+',
#  'Dental Visit - American Indian/Alaska Native',
#  'Dental Visit - Asian',
#  'Dental Visit - Black',
#  'Dental Visit - College Grad',
#  'Dental Visit - Female',
#  'Dental Visit - Hawaiian/Pacific Islander',
#  'Dental Visit - High School/GED',
#  'Dental Visit - Hispanic',
#  'Dental Visit - Less Than $25,000',
#  'Dental Visit - Less Than High School',
#  'Dental Visit - Male',
#  'Dental Visit - Multiracial',
#  'Dental Visit - Other Race',
#  'Dental Visit - Some Post-High School',
#  'Dental Visit - White',
#  'Dependency',
#  'Dependency - Black',
#  'Dependency - Hispanic',
#  'Dependency - White',
#  'Depression',
#  'Depression - $25-$49,999',
#  'Depression - $50-$74,999',
#  'Depression - $75,000 or More',
#  'Depression - Ages 18-44',
#  'Depression - Ages 45-64',
#  'Depression - Ages 65+',
#  'Depression - American Indian/Alaska Native',
#  'Depression - Asian',
#  'Depression - Black',
#  'Depression - College Grad',
#  'Depression - Female',
#  'Depression - Hawaiian/Pacific Islander',
#  'Depression - High School/GED',
#  'Depression - Hispanic',
#  'Depression - Less Than $25,000',
#  'Depression - Less Than High School',
#  'Depression - Male',
#  'Depression - Multiracial',
#  'Depression - Other Race',
#  'Depression - Some Post-High School',
#  'Depression - White',
#  'Diabetes',
#  'Diabetes - $25-$49,999',
#  'Diabetes - $50-$74,999',
#  'Diabetes - $75,000 or More',
#  'Diabetes - Ages 18-44',
#  'Diabetes - Ages 45-64',
#  'Diabetes - Ages 65+',
#  'Diabetes - American Indian/Alaska Native',
#  'Diabetes - Asian',
#  'Diabetes - Black',
#  'Diabetes - College Grad',
#  'Diabetes - Female',
#  'Diabetes - Hawaiian/Pacific Islander',
#  'Diabetes - High School/GED',
#  'Diabetes - Hispanic',
#  'Diabetes - Less Than $25,000',
#  'Diabetes - Less Than High School',
#  'Diabetes - Male',
#  'Diabetes - Multiracial',
#  'Diabetes - Other Race',
#  'Diabetes - Some Post-High School',
#  'Diabetes - White',
#  'Discrimination',
#  'Domestic violence',
#  'Drinking Water Violations',
#  'Drive Alone to Work',
#  'Drive Alone to Work - Men',
#  'Drive Alone to Work - Women',
#  'Drug Deaths',
#  'Drug Deaths - Ages 15-24',
#  'Drug Deaths - Ages 25-34',
#  'Drug Deaths - Ages 35-44',
#  'Drug Deaths - Ages 45-54',
#  'Drug Deaths - Ages 55-64',
#  'Drug Deaths - Ages 65-74',
#  'Drug Deaths - American Indian/Alaska Native',
#  'Drug Deaths - Asian/Pacific Islander',
#  'Drug Deaths - Black',
#  'Drug Deaths - Female',
#  'Drug Deaths - Hispanic',
#  'Drug Deaths - Male',
#  'Drug Deaths - White',
#  'E-cigarette Use',
#  'E-cigarette Use - $25-$49,999',
#  'E-cigarette Use - $50-$74,999',
#  'E-cigarette Use - $75,000 or More',
#  'E-cigarette Use - Ages 18-44',
#  'E-cigarette Use - Ages 45-64',
#  'E-cigarette Use - Ages 65+',
#  'E-cigarette Use - American Indian/Alaska Native',
#  'E-cigarette Use - Asian',
#  'E-cigarette Use - Black',
#  'E-cigarette Use - College Grad',
#  'E-cigarette Use - Female',
#  'E-cigarette Use - Hawaiian/Pacific Islander',
#  'E-cigarette Use - High School/GED',
#  'E-cigarette Use - Hispanic',
#  'E-cigarette Use - Less Than $25,000',
#  'E-cigarette Use - Less Than High School',
#  'E-cigarette Use - Male',
#  'E-cigarette Use - Multiracial',
#  'E-cigarette Use - Other Race',
#  'E-cigarette Use - Some Post-High School',
#  'E-cigarette Use - White',
#  'Economic Hardship Index',
#  'Economic Resources - Annual',
#  'Education - Annual',
#  'Education - Less Than High School',
#  'Education - Less Than High School - Black',
#  'Education - Less Than High School - Hispanic',
#  'Education - Less Than High School - White',
#  'Excessive Drinking',
#  'Excessive Drinking - $25-$49,999',
#  'Excessive Drinking - $50-$74,999',
#  'Excessive Drinking - $75,000 or More',
#  'Excessive Drinking - Ages 18-44',
#  'Excessive Drinking - Ages 45-64',
#  'Excessive Drinking - Ages 65+',
#  'Excessive Drinking - American Indian/Alaska Native',
#  'Excessive Drinking - Asian',
#  'Excessive Drinking - Black',
#  'Excessive Drinking - College Grad',
#  'Excessive Drinking - Female',
#  'Excessive Drinking - Hawaiian/Pacific Islander',
#  'Excessive Drinking - High School/GED',
#  'Excessive Drinking - Hispanic',
#  'Excessive Drinking - Less Than $25,000',
#  'Excessive Drinking - Less Than High School',
#  'Excessive Drinking - Male',
#  'Excessive Drinking - Multiracial',
#  'Excessive Drinking - Other Race',
#  'Excessive Drinking - Some Post-High School',
#  'Excessive Drinking - White',
#  'Exercise',
#  'Exercise - $25-$49,999',
#  'Exercise - $50-$74,999',
#  'Exercise - $75,000 or More',
#  'Exercise - Ages 18-44',
#  'Exercise - Ages 45-64',
#  'Exercise - Ages 65+',
#  'Exercise - American Indian/Alaska Native',
#  'Exercise - Asian',
#  'Exercise - Black',
#  'Exercise - College Grad',
#  'Exercise - Female',
#  'Exercise - Hawaiian/Pacific Islander',
#  'Exercise - High School/GED',
#  'Exercise - Hispanic',
#  'Exercise - Less Than $25,000',
#  'Exercise - Less Than High School',
#  'Exercise - Male',
#  'Exercise - Multiracial',
#  'Exercise - Other Race',
#  'Exercise - Some Post-High School',
#  'Exercise - White',
#  'Exercise - Women',
#  'Exercise - Women - $25-$49,999',
#  'Exercise - Women - $50-$74,999',
#  'Exercise - Women - $75,000 or More',
#  'Exercise - Women - Ages 18-24',
#  'Exercise - Women - Ages 25-34',
#  'Exercise - Women - Ages 35-44',
#  'Exercise - Women - American Indian/Alaska Native',
#  'Exercise - Women - Asian',
#  'Exercise - Women - Black',
#  'Exercise - Women - College Grad',
#  'Exercise - Women - Hawaiian/Pacific Islander',
#  'Exercise - Women - High School/GED',
#  'Exercise - Women - Hispanic',
#  'Exercise - Women - Less Than $25,000',
#  'Exercise - Women - Less Than High School',
#  'Exercise - Women - Multiracial',
#  'Exercise - Women - Other Race',
#  'Exercise - Women - Some Post-High School',
#  'Exercise - Women - White',
#  'Flu Vaccination',
#  'Flu Vaccination - $25-$49,999',
#  'Flu Vaccination - $50-$74,999',
#  'Flu Vaccination - $75,000 or More',
#  'Flu Vaccination - 18-44',
#  'Flu Vaccination - 45-64',
#  'Flu Vaccination - 65+',
#  'Flu Vaccination - American Indian/Alaska Native',
#  'Flu Vaccination - Asian',
#  'Flu Vaccination - Black',
#  'Flu Vaccination - College Grad',
#  'Flu Vaccination - Female',
#  'Flu Vaccination - Hawaiian/Pacific Islander',
#  'Flu Vaccination - High School/GED',
#  'Flu Vaccination - Hispanic',
#  'Flu Vaccination - Less Than $25,000',
#  'Flu Vaccination - Less Than HS',
#  'Flu Vaccination - Male',
#  'Flu Vaccination - Multiracial',
#  'Flu Vaccination - Other Race',
#  'Flu Vaccination - Some Post-High School',
#  'Flu Vaccination - White',
#  'Food Insecurity',
#  'Fourth Grade Reading Proficiency',
#  'Fourth Grade Reading Proficiency - American Indian/Alaska Native',
#  'Fourth Grade Reading Proficiency - Asian/Pacific Islander',
#  'Fourth Grade Reading Proficiency - Black',
#  'Fourth Grade Reading Proficiency - Hispanic',
#  'Fourth Grade Reading Proficiency - White',
#  'Frequent Mental Distress',
#  'Frequent Mental Distress - $25-$49,999',
#  'Frequent Mental Distress - $50-$74,999',
#  'Frequent Mental Distress - $75,000 or More',
#  'Frequent Mental Distress - Ages 18-44',
#  'Frequent Mental Distress - Ages 45-64',
#  'Frequent Mental Distress - Ages 65+',
#  'Frequent Mental Distress - American Indian/Alaska Native',
#  'Frequent Mental Distress - Asian',
#  'Frequent Mental Distress - Black',
#  'Frequent Mental Distress - College Grad',
#  'Frequent Mental Distress - Female',
#  'Frequent Mental Distress - Hawaiian/Pacific Islander',
#  'Frequent Mental Distress - High School/GED',
#  'Frequent Mental Distress - Hispanic',
#  'Frequent Mental Distress - Less Than $25,000',
#  'Frequent Mental Distress - Less Than High School',
#  'Frequent Mental Distress - Male',
#  'Frequent Mental Distress - Multiracial',
#  'Frequent Mental Distress - Other Race',
#  'Frequent Mental Distress - Some Post-High School',
#  'Frequent Mental Distress - White',
#  'Frequent Physical Distress',
#  'Frequent Physical Distress - $25-$49,999',
#  'Frequent Physical Distress - $50-$74,999',
#  'Frequent Physical Distress - $75,000 or More',
#  'Frequent Physical Distress - Ages 18-44',
#  'Frequent Physical Distress - Ages 45-64',
#  'Frequent Physical Distress - Ages 65+',
#  'Frequent Physical Distress - American Indian/Alaska Native',
#  'Frequent Physical Distress - Asian',
#  'Frequent Physical Distress - Black',
#  'Frequent Physical Distress - College Grad',
#  'Frequent Physical Distress - Female',
#  'Frequent Physical Distress - Hawaiian/Pacific Islander',
#  'Frequent Physical Distress - High School/GED',
#  'Frequent Physical Distress - Hispanic',
#  'Frequent Physical Distress - Less Than $25,000',
#  'Frequent Physical Distress - Less Than High School',
#  'Frequent Physical Distress - Male',
#  'Frequent Physical Distress - Multiracial',
#  'Frequent Physical Distress - Other Race',
#  'Frequent Physical Distress - Some Post-High School',
#  'Frequent Physical Distress - White',
#  'Fruit and Vegetable Consumption',
#  'Fruit and Vegetable Consumption - $25-$49,999',
#  'Fruit and Vegetable Consumption - $50-$74,999',
#  'Fruit and Vegetable Consumption - $75,000 or More',
#  'Fruit and Vegetable Consumption - Ages 18-44',
#  'Fruit and Vegetable Consumption - Ages 45-64',
#  'Fruit and Vegetable Consumption - Ages 65+',
#  'Fruit and Vegetable Consumption - American Indian/Alaska Native',
#  'Fruit and Vegetable Consumption - Asian',
#  'Fruit and Vegetable Consumption - Black',
#  'Fruit and Vegetable Consumption - College Grad',
#  'Fruit and Vegetable Consumption - Female',
#  'Fruit and Vegetable Consumption - Hawaiian/Pacific Islander',
#  'Fruit and Vegetable Consumption - High School/GED',
#  'Fruit and Vegetable Consumption - Hispanic',
#  'Fruit and Vegetable Consumption - Less Than $25,000',
#  'Fruit and Vegetable Consumption - Less Than High School',
#  'Fruit and Vegetable Consumption - Male',
#  'Fruit and Vegetable Consumption - Multiracial',
#  'Fruit and Vegetable Consumption - Other Race',
#  'Fruit and Vegetable Consumption - Some Post-High School',
#  'Fruit and Vegetable Consumption - White',
#  'Fruit and Vegetable Consumption - Women',
#  'Fruit and Vegetable Consumption - Women - $25-$49,999',
#  'Fruit and Vegetable Consumption - Women - $50-$74,999',
#  'Fruit and Vegetable Consumption - Women - $75,000 or More',
#  'Fruit and Vegetable Consumption - Women - Ages 18-24',
#  'Fruit and Vegetable Consumption - Women - Ages 25-34',
#  'Fruit and Vegetable Consumption - Women - Ages 35-44',
#  'Fruit and Vegetable Consumption - Women - American Indian/Alaska Native',
#  'Fruit and Vegetable Consumption - Women - Asian',
#  'Fruit and Vegetable Consumption - Women - Black',
#  'Fruit and Vegetable Consumption - Women - College Grad',
#  'Fruit and Vegetable Consumption - Women - Hawaiian/Pacific Islander',
#  'Fruit and Vegetable Consumption - Women - High School/GED',
#  'Fruit and Vegetable Consumption - Women - Hispanic',
#  'Fruit and Vegetable Consumption - Women - Less Than $25,000',
#  'Fruit and Vegetable Consumption - Women - Less Than High School',
#  'Fruit and Vegetable Consumption - Women - Multiracial',
#  'Fruit and Vegetable Consumption - Women - Other Race',
#  'Fruit and Vegetable Consumption - Women - Some Post-High School',
#  'Fruit and Vegetable Consumption - Women - White',
#  'Health Outcomes',
#  'Heavy Drinking',
#  'High Blood Pressure',
#  'High Blood Pressure - $25-$49,999',
#  'High Blood Pressure - $50-$74,999',
#  'High Blood Pressure - $75,000 or More',
#  'High Blood Pressure - Ages 18-44',
#  'High Blood Pressure - Ages 45-64',
#  'High Blood Pressure - Ages 65+',
#  'High Blood Pressure - American Indian/Alaska Native',
#  'High Blood Pressure - Asian',
#  'High Blood Pressure - Black',
#  'High Blood Pressure - College Grad',
#  'High Blood Pressure - Female',
#  'High Blood Pressure - Hawaiian/Pacific Islander',
#  'High Blood Pressure - High School/GED',
#  'High Blood Pressure - Hispanic',
#  'High Blood Pressure - Less Than $25,000',
#  'High Blood Pressure - Less Than High School',
#  'High Blood Pressure - Male',
#  'High Blood Pressure - Multiracial',
#  'High Blood Pressure - Other Race',
#  'High Blood Pressure - Some Post-High School',
#  'High Blood Pressure - White',
#  'High Cholesterol',
#  'High Cholesterol - $25-$49,999',
#  'High Cholesterol - $50-$74,999',
#  'High Cholesterol - $75,000 or More',
#  'High Cholesterol - Ages 18-44',
#  'High Cholesterol - Ages 45-64',
#  'High Cholesterol - Ages 65+',
#  'High Cholesterol - American Indian/Alaska Native',
#  'High Cholesterol - Asian',
#  'High Cholesterol - Black',
#  'High Cholesterol - College Grad',
#  'High Cholesterol - Female',
#  'High Cholesterol - Hawaiian/Pacific Islander',
#  'High Cholesterol - High School/GED',
#  'High Cholesterol - Hispanic',
#  'High Cholesterol - Less Than $25,000',
#  'High Cholesterol - Less Than High School',
#  'High Cholesterol - Male',
#  'High Cholesterol - Multiracial',
#  'High Cholesterol - Other Race',
#  'High Cholesterol - Some Post-High School',
#  'High Cholesterol - White',
#  'High Health Status',
#  'High Health Status - $25-$49,999',
#  'High Health Status - $50-$74,999',
#  'High Health Status - $75,000 or More',
#  'High Health Status - Ages 18-44',
#  'High Health Status - Ages 45-64',
#  'High Health Status - Ages 65+',
#  'High Health Status - American Indian/Alaska Native',
#  'High Health Status - Asian',
#  'High Health Status - Black',
#  'High Health Status - College Grad',
#  'High Health Status - Female',
#  'High Health Status - Hawaiian/Pacific Islander',
#  'High Health Status - High School/GED',
#  'High Health Status - Hispanic',
#  'High Health Status - Less Than $25,000',
#  'High Health Status - Less Than High School',
#  'High Health Status - Male',
#  'High Health Status - Multiracial',
#  'High Health Status - Other Race',
#  'High Health Status - Some Post-High School',
#  'High Health Status - White',
#  'High School Graduation',
#  'High School Graduation - American Indian/Alaska Native',
#  'High School Graduation - Asian/Pacific Islander',
#  'High School Graduation - Black',
#  'High School Graduation - Hispanic',
#  'High School Graduation - White',
#  'High School Graduation Racial Disparity',
#  'High-risk HIV Behaviors',
#  'High-risk HIV Behaviors - $25-$49,999',
#  'High-risk HIV Behaviors - $50-$74,999',
#  'High-risk HIV Behaviors - $75,000 or More',
#  'High-risk HIV Behaviors - Ages 18-44',
#  'High-risk HIV Behaviors - Ages 45-64',
#  'High-risk HIV Behaviors - Ages 65+',
#  'High-risk HIV Behaviors - American Indian/Alaska Native',
#  'High-risk HIV Behaviors - Asian',
#  'High-risk HIV Behaviors - Black',
#  'High-risk HIV Behaviors - College Grad',
#  'High-risk HIV Behaviors - Female',
#  'High-risk HIV Behaviors - Hawaiian/Pacific Islander',
#  'High-risk HIV Behaviors - High School/GED',
#  'High-risk HIV Behaviors - Hispanic',
#  'High-risk HIV Behaviors - Less Than $25,000',
#  'High-risk HIV Behaviors - Less Than High School',
#  'High-risk HIV Behaviors - Male',
#  'High-risk HIV Behaviors - Multiracial',
#  'High-risk HIV Behaviors - Other Race',
#  'High-risk HIV Behaviors - Some Post-High School',
#  'High-risk HIV Behaviors - White',
#  'High-speed Internet',
#  'High-speed Internet - American Indian/Alaska Native',
#  'High-speed Internet - Asian',
#  'High-speed Internet - Black',
#  'High-speed Internet - Hawaiian/Pacific Islander',
#  'High-speed Internet - Hispanic',
#  'High-speed Internet - Multiracial',
#  'High-speed Internet - Other Race',
#  'High-speed Internet - White',
#  'Homeownership',
#  'Homeownership - American Indian/Alaska Native',
#  'Homeownership - Asian',
#  'Homeownership - Black',
#  'Homeownership - Hawaiian/Pacific Islander',
#  'Homeownership - Hispanic',
#  'Homeownership - Multiracial',
#  'Homeownership - Other Race',
#  'Homeownership - White',
#  'Homeownership Racial Disparity',
#  'Housing and Transit - Annual',
#  'Housing With Lead Risk',
#  'HPV Immunization - Females',
#  'HPV Immunization - Males',
#  'HPV Vaccination',
#  'Illicit Drug Use (excluding opioids and cannabis)',
#  'Illicit Opioid Use',
#  'Immunizations - Annual',
#  'Income Inequality',
#  'Insufficient Sleep',
#  'Insufficient Sleep - $25-$49,999',
#  'Insufficient Sleep - $50-$74,999',
#  'Insufficient Sleep - $75,000 or More',
#  'Insufficient Sleep - Ages 18-44',
#  'Insufficient Sleep - Ages 45-64',
#  'Insufficient Sleep - Ages 65+',
#  'Insufficient Sleep - American Indian/Alaska Native',
#  'Insufficient Sleep - Asian',
#  'Insufficient Sleep - Black',
#  'Insufficient Sleep - College Grad',
#  'Insufficient Sleep - Female',
#  'Insufficient Sleep - Hawaiian/Pacific Islander',
#  'Insufficient Sleep - High School/GED',
#  'Insufficient Sleep - Hispanic',
#  'Insufficient Sleep - Less Than $25,000',
#  'Insufficient Sleep - Less Than High School',
#  'Insufficient Sleep - Male',
#  'Insufficient Sleep - Multiracial',
#  'Insufficient Sleep - Other Race',
#  'Insufficient Sleep - Some Post-High School',
#  'Insufficient Sleep - White',
#  'Low Birthweight',
#  'Low Birthweight - American Indian/Alaska Native',
#  'Low Birthweight - Asian',
#  'Low Birthweight - Black',
#  'Low Birthweight - College Graduate',
#  'Low Birthweight - Hawaiian/Pacific Islander',
#  'Low Birthweight - High School Graduate',
#  'Low Birthweight - Hispanic',
#  'Low Birthweight - Less Than High School',
#  'Low Birthweight - Mother Ages 15-19',
#  'Low Birthweight - Mother Ages 20-24',
#  'Low Birthweight - Mother Ages 25-29',
#  'Low Birthweight - Mother Ages 30-34',
#  'Low Birthweight - Mother Ages 35-39',
#  'Low Birthweight - Mother Ages 40-44',
#  'Low Birthweight - Multiracial',
#  'Low Birthweight - Some Post-High School',
#  'Low Birthweight - White',
#  'Low Birthweight Racial Disparity',
#  'Mental Health Providers',
#  'Mental illness',
#  'Mortality - Annual',
#  'Multiple Chronic Conditions',
#  'Multiple Chronic Conditions - $25-$49,999',
#  'Multiple Chronic Conditions - $50-$74,999',
#  'Multiple Chronic Conditions - $75,000 or More',
#  'Multiple Chronic Conditions - Ages 18-44',
#  'Multiple Chronic Conditions - Ages 45-64',
#  'Multiple Chronic Conditions - Ages 65+',
#  'Multiple Chronic Conditions - American Indian/Alaska Native',
#  'Multiple Chronic Conditions - Asian',
#  'Multiple Chronic Conditions - Black',
#  'Multiple Chronic Conditions - College Grad',
#  'Multiple Chronic Conditions - Female',
#  'Multiple Chronic Conditions - Hawaiian/Pacific Islander',
#  'Multiple Chronic Conditions - High School/GED',
#  'Multiple Chronic Conditions - Hispanic',
#  'Multiple Chronic Conditions - Less Than $25,000',
#  'Multiple Chronic Conditions - Less Than High School',
#  'Multiple Chronic Conditions - Male',
#  'Multiple Chronic Conditions - Multiracial',
#  'Multiple Chronic Conditions - Other Race',
#  'Multiple Chronic Conditions - Some Post-High School',
#  'Multiple Chronic Conditions - White',
#  'Neighborhood violence',
#  'Non-medical Drug Use - $25-$74,999',
#  'Non-medical Drug Use - $75,000 or More',
#  'Non-medical Drug Use - American Indian/Alaska Native',
#  'Non-medical Drug Use - Asian',
#  'Non-medical Drug Use - Black',
#  'Non-medical Drug Use - College Grad',
#  'Non-medical Drug Use - Female',
#  'Non-medical Drug Use - Hawaiian/Pacific Islander',
#  'Non-medical Drug Use - High School/GED',
#  'Non-medical Drug Use - Hispanic',
#  'Non-medical Drug Use - Less Than $25,000',
#  'Non-medical Drug Use - Less Than High School',
#  'Non-medical Drug Use - Male',
#  'Non-medical Drug Use - Other Race',
#  'Non-medical Drug Use - Past Year',
#  'Non-medical Drug Use - Some Post-High School',
#  'Non-medical Drug Use - White',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - $25-$74,999',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - $75,000 or More',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - American Indian/Alaska Native',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - Asian',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - Black',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - College Grad',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - Female',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - Hawaiian/Pacific Islander',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - High School/GED',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - Hispanic',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - Less Than $25,000',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - Less Than High School',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - Male',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - Other Race',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - Some Post-High School',
#  'Non-medical Use of Other Prescription Drugs (excludes cannabis) - White',
#  'Non-medical Use of Prescription Drugs (excluding opioids and cannabis)',
#  'Non-medical Use of Prescription Opioids',
#  'Non-medical Use of Prescription Opioids - $25-$74,999',
#  'Non-medical Use of Prescription Opioids - $75,000 or More',
#  'Non-medical Use of Prescription Opioids - American Indian/Alaska Native',
#  'Non-medical Use of Prescription Opioids - Asian',
#  'Non-medical Use of Prescription Opioids - Black',
#  'Non-medical Use of Prescription Opioids - College Grad',
#  'Non-medical Use of Prescription Opioids - Female',
#  'Non-medical Use of Prescription Opioids - Hawaiian/Pacific Islander',
#  'Non-medical Use of Prescription Opioids - High School/GED',
#  'Non-medical Use of Prescription Opioids - Hispanic',
#  'Non-medical Use of Prescription Opioids - Less Than $25,000',
#  'Non-medical Use of Prescription Opioids - Less Than High School',
#  'Non-medical Use of Prescription Opioids - Male',
#  'Non-medical Use of Prescription Opioids - Other Race',
#  'Non-medical Use of Prescription Opioids - Some Post-High School',
#  'Non-medical Use of Prescription Opioids - White',
#  'Non-smoking Regulation',
#  'Nutrition and Physical Activity - Annual',
#  'Obesity',
#  'Obesity - $25-$49,999',
#  'Obesity - $50-$74,999',
#  'Obesity - $75,000 or More',
#  'Obesity - Ages 18-44',
#  'Obesity - Ages 45-64',
#  'Obesity - Ages 65+',
#  'Obesity - American Indian/Alaska Native',
#  'Obesity - Asian',
#  'Obesity - Black',
#  'Obesity - College Grad',
#  'Obesity - Female',
#  'Obesity - Hawaiian/Pacific Islander',
#  'Obesity - High School/GED',
#  'Obesity - Hispanic',
#  'Obesity - Less Than $25,000',
#  'Obesity - Less Than High School',
#  'Obesity - Male',
#  'Obesity - Multiracial',
#  'Obesity - Other Race',
#  'Obesity - Some Post-High School',
#  'Obesity - White',
#  'Occupational Fatalities',
#  'Overall - Annual',
#  'Parent or guardian death',
#  'Parent or guardian divorce or separation',
#  'Parent or guardian time in jail',
#  'Per Capita Income',
#  'Per Capita Income - Black',
#  'Per Capita Income - Hispanic',
#  'Per Capita Income - White',
#  'Physical Environment',
#  'Physical Health - Annual',
#  'Physical Inactivity',
#  'Physical Inactivity - $25-$49,999',
#  'Physical Inactivity - $50-$74,999',
#  'Physical Inactivity - $75,000 or More',
#  'Physical Inactivity - Ages 18-44',
#  'Physical Inactivity - Ages 45-64',
#  'Physical Inactivity - Ages 65+',
#  'Physical Inactivity - American Indian/Alaska Native',
#  'Physical Inactivity - Asian',
#  'Physical Inactivity - Black',
#  'Physical Inactivity - College Grad',
#  'Physical Inactivity - Female',
#  'Physical Inactivity - Hawaiian/Pacific Islander',
#  'Physical Inactivity - High School/GED',
#  'Physical Inactivity - Hispanic',
#  'Physical Inactivity - Less Than $25,000',
#  'Physical Inactivity - Less Than High School',
#  'Physical Inactivity - Male',
#  'Physical Inactivity - Multiracial',
#  'Physical Inactivity - Other Race',
#  'Physical Inactivity - Some Post-High School',
#  'Physical Inactivity - White',
#  'Population - Adults Ages 18-64 - American Indian Alaska Native',
#  'Population - Adults Ages 18-64 - Asian',
#  'Population - Adults Ages 18-64 - Black ',
#  'Population - Adults Ages 18-64 - Hawaiian/Pacific Islander',
#  'Population - Adults Ages 18-64 - Hispanic',
#  'Population - Adults Ages 18-64 - Multiracial',
#  'Population - Adults Ages 18-64 - White',
#  'Population - American Indian Alaska Native',
#  'Population - Asian',
#  'Population - Black',
#  'Population - Hawaiian/Pacific Islander',
#  'Population - Hispanic/Latino',
#  'Population - Multiracial',
#  'Population - White',
#  'Population Ages 65+',
#  'Population Ages 65+ - American Indian Alaska Native',
#  'Population Ages 65+ - Asian',
#  'Population Ages 65+ - Black ',
#  'Population Ages 65+ - Female',
#  'Population Ages 65+ - Hispanic',
#  'Population Ages 65+ - Male',
#  'Population Ages 65+ - Multiracial',
#  'Population Ages 65+ - White',
#  'Population-Adults Ages 18-64',
#  'Population-Children (Under age 18)',
#  'Poverty',
#  'Premature Death',
#  'Premature Death - American Indian/Alaska Native',
#  'Premature Death - Asian/Pacific Islander',
#  'Premature Death - Black',
#  'Premature Death - Hispanic',
#  'Premature Death - White',
#  'Premature Death (three-year estimate)',
#  'Premature Death Racial Disparity',
#  'Preventable Hospitalizations',
#  'Preventable Hospitalizations - American Indian/Alaska Native',
#  'Preventable Hospitalizations - Asian/Pacific Islander',
#  'Preventable Hospitalizations - Black',
#  'Preventable Hospitalizations - Female',
#  'Preventable Hospitalizations - Hispanic',
#  'Preventable Hospitalizations - Male',
#  'Preventable Hospitalizations - Other Race',
#  'Preventable Hospitalizations - White',
#  'Preventive Clinical Services - Annual',
#  'Primary Care Providers',
#  'Providers - Annual',
#  'Public Health Funding',
#  'Quality of Care - Annual',
#  'Residential Segregation - Black/White',
#  'Risk Factors - Annual',
#  'Risk-screening Environmental Indicator Score',
#  'Rural Population',
#  'Severe Housing Problems',
#  'Severe Housing Problems - American Indian/Alaska Native',
#  'Severe Housing Problems - Asian/Pacific Islander',
#  'Severe Housing Problems - Black',
#  'Severe Housing Problems - Hispanic',
#  'Severe Housing Problems - White',
#  'Sexual Health - Annual',
#  'Sleep Health - Annual',
#  'Smoking',
#  'Smoking - $25-$49,999',
#  'Smoking - $50-$74,999',
#  'Smoking - $75,000 or More',
#  'Smoking - Ages 18-44',
#  'Smoking - Ages 45-64',
#  'Smoking - Ages 65+',
#  'Smoking - American Indian/Alaska Native',
#  'Smoking - Asian',
#  'Smoking - Black',
#  'Smoking - College Grad',
#  'Smoking - Female',
#  'Smoking - Hawaiian/Pacific Islander',
#  'Smoking - High School/GED',
#  'Smoking - Hispanic',
#  'Smoking - Less Than $25,000',
#  'Smoking - Less Than High School',
#  'Smoking - Male',
#  'Smoking - Multiracial',
#  'Smoking - Other Race',
#  'Smoking - Some Post-High School',
#  'Smoking - White',
#  'Smoking and Tobacco Use - Annual',
#  'Social and Economic Factors',
#  'Social Support and Engagement - Annual',
#  'Substance misuse',
#  'Suicide',
#  'Suicide - Ages 15-24',
#  'Suicide - Ages 25-34',
#  'Suicide - Ages 35-44',
#  'Suicide - Ages 45-54',
#  'Suicide - Ages 55-64',
#  'Suicide - Ages 65-74',
#  'Suicide - Ages 75-84',
#  'Suicide - Ages 85+',
#  'Suicide - American Indian/Alaska Native',
#  'Suicide - Asian/Pacific Islander',
#  'Suicide - Black',
#  'Suicide - Female',
#  'Suicide - Hispanic',
#  'Suicide - Male',
#  'Suicide - White',
#  'Teen Births',
#  'Teen Births - American Indian/Alaska Native',
#  'Teen Births - Asian/Pacific Islander',
#  'Teen Births - Black',
#  'Teen Births - Hispanic',
#  'Teen Births - White',
#  'Total Population',
#  'Transportation Energy Use',
#  'Unemployment',
#  'Unemployment - Black',
#  'Unemployment - Hispanic',
#  'Unemployment - White',
#  'Uninsured',
#  'Use of Cannabis - $25-$74,999',
#  'Use of Cannabis - $75,000 or More',
#  'Use of Cannabis - American Indian/Alaska Native',
#  'Use of Cannabis - Asian',
#  'Use of Cannabis - Black',
#  'Use of Cannabis - College Grad',
#  'Use of Cannabis - Female',
#  'Use of Cannabis - Hawaiian/Pacific Islander',
#  'Use of Cannabis - High School/GED',
#  'Use of Cannabis - Hispanic',
#  'Use of Cannabis - Less Than $25,000',
#  'Use of Cannabis - Less Than High School',
#  'Use of Cannabis - Male',
#  'Use of Cannabis - Other Race',
#  'Use of Cannabis - Some Post-High School',
#  'Use of Cannabis - White',
#  'Use of Illicit Opioids - $25-$74,999',
#  'Use of Illicit Opioids - $75,000 or More',
#  'Use of Illicit Opioids - American Indian/Alaska Native',
#  'Use of Illicit Opioids - Asian',
#  'Use of Illicit Opioids - Black',
#  'Use of Illicit Opioids - College Grad',
#  'Use of Illicit Opioids - Female',
#  'Use of Illicit Opioids - Hawaiian/Pacific Islander',
#  'Use of Illicit Opioids - High School/GED',
#  'Use of Illicit Opioids - Hispanic',
#  'Use of Illicit Opioids - Less Than $25,000',
#  'Use of Illicit Opioids - Less Than High School',
#  'Use of Illicit Opioids - Male',
#  'Use of Illicit Opioids - Other Race',
#  'Use of Illicit Opioids - Some Post-High School',
#  'Use of Illicit Opioids - White',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - $25-$74,999',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - $75,000 or More',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - American Indian/Alaska Native',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - Asian',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - Black',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - College Grad',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - Female',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - Hawaiian/Pacific Islander',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - High School/GED',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - Hispanic',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - Less Than $25,000',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - Less Than High School',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - Male',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - Other Race',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - Some Post-High School',
#  'Use of Other Illicit Drugs (excludes opioids and cannabis) - White',
#  'Violent Crime',
#  'Volunteerism',
#  'Voter Participation (Average)',
#  'Voter Participation (Midterm)',
#  'Voter Participation (Presidential)',
#  'Voter Participation (Presidential) - Ages 18-24 ',
#  'Voter Participation (Presidential) - Ages 25-34',
#  'Voter Participation (Presidential) - Ages 35-44',
#  'Voter Participation (Presidential) - Ages 45-64',
#  'Voter Participation (Presidential) - Ages 65+ ',
#  'Voter Participation (Presidential) - Asian',
#  'Voter Participation (Presidential) - Black',
#  'Voter Participation (Presidential) - Female',
#  'Voter Participation (Presidential) - Hispanic',
#  'Voter Participation (Presidential) - Male',
#  'Voter Participation (Presidential) - White',
#  ...]

# %%
#health indicators dataframe merged with total deaths per state 
health=pd.merge(state_health_df, df, on='State', how='outer')
health.head()
# Out:
#                      Measure Name   State  Rank   Value  Score        Date  \
# 0         Access to Care - Annual  Alaska  20.0   0.494  0.494  2022-10-15
# 1   Adverse Childhood Experiences  Alaska  44.0  18.900  1.310  2022-10-15
# 2  Air and Water Quality - Annual  Alaska  43.0  -0.398 -0.398  2022-10-15
# 3                   Air Pollution  Alaska  16.0   6.800 -0.940  2022-10-15
# 4       All Determinants - Annual  Alaska  31.0  -0.115 -0.115  2022-10-15
#
#    Fips   Cases  Deaths
# 0     2  305705    1350
# 1     2  305705    1350
# 2     2  305705    1350
# 3     2  305705    1350
# 4     2  305705    1350

# %%
cardio_data = health[health['Measure Name'] == 'Cardiovascular Diseases']
cardio_corr = cardio_data[['Rank','Value','Score','Deaths']].corr()

print(cardio_data.head())
print(cardio_corr)
# Out:
#                  Measure Name       State  Rank  Value  Score        Date  \
# 97    Cardiovascular Diseases      Alaska   4.0    6.9  -0.91  2022-10-15
# 1105  Cardiovascular Diseases     Alabama  44.0   11.0   1.37  2022-10-15
# 2113  Cardiovascular Diseases    Arkansas  48.0   12.2   2.00  2022-10-15
# 3121  Cardiovascular Diseases     Arizona  24.0    8.1  -0.25  2022-10-15
# 4129  Cardiovascular Diseases  California   6.0    7.0  -0.89  2022-10-15
#
#       Fips     Cases  Deaths
# 97       2    305705    1350
# 1105     1   1528739   20505
# 2113     5    955798   12371
# 3121     4   2277635   31455
# 4129     6  11317958   96460
#             Rank     Value     Score    Deaths
# Rank    1.000000  0.959671  0.974553 -0.012094
# Value   0.959671  1.000000  0.991404  0.013697
# Score   0.974553  0.991404  1.000000  0.022798
# Deaths -0.012094  0.013697  0.022798  1.000000

# %%
#It seems like cardiovascular disease doesn't have much correlation to deaths. Let's check out other health indicators.
access_data = health.loc[health['Measure Name'] == 'Access to Care - Annual']
print(access_data.head())

access_corr = access_data[['Rank','Value','Score','Deaths']].corr()
print(access_corr)

#save dataframe with access to healthcare data per state 
access_data.to_csv('access_data.csv')
# Out:
#                  Measure Name       State  Rank  Value  Score        Date  \
# 0     Access to Care - Annual      Alaska  20.0  0.494  0.494  2022-10-15
# 1008  Access to Care - Annual     Alabama  45.0 -0.900 -0.900  2022-10-15
# 2016  Access to Care - Annual    Arkansas  43.0 -0.681 -0.681  2022-10-15
# 3024  Access to Care - Annual     Arizona  42.0 -0.657 -0.657  2022-10-15
# 4032  Access to Care - Annual  California  18.0  0.569  0.569  2022-10-15
#
#       Fips     Cases  Deaths
# 0        2    305705    1350
# 1008     1   1528739   20505
# 2016     5    955798   12371
# 3024     4   2277635   31455
# 4032     6  11317958   96460
#             Rank     Value     Score    Deaths
# Rank    1.000000 -0.980870 -0.980870  0.195218
# Value  -0.980870  1.000000  1.000000 -0.265643
# Score  -0.980870  1.000000  1.000000 -0.265643
# Deaths  0.195218 -0.265643 -0.265643  1.000000

# %% [markdown]
# It looks like the rank, value and score of access to health care has a higher correlation than cardiovascular disease.
# This relationship definitely makes sense. What about the other health indicators?

# %%
housing_data = health.loc[health['Measure Name'] == 'Crowded Housing']
print(housing_data.head())

housing_corr = housing_data[['Rank','Value','Score','Deaths']].corr()
print(housing_corr)
# Out:
#          Measure Name       State  Rank  Value  Score        Date  Fips  \
# 196   Crowded Housing      Alaska  48.0    6.7   2.00  2022-10-15     2
# 1204  Crowded Housing     Alabama   2.0    1.5  -1.14  2022-10-15     1
# 2212  Crowded Housing    Arkansas  36.0    2.8  -0.32  2022-10-15     5
# 3220  Crowded Housing     Arizona  44.0    4.3   0.64  2022-10-15     4
# 4228  Crowded Housing  California  49.0    8.2   2.00  2022-10-15     6
#
#          Cases  Deaths
# 196     305705    1350
# 1204   1528739   20505
# 2212    955798   12371
# 3220   2277635   31455
# 4228  11317958   96460
#             Rank     Value     Score    Deaths
# Rank    1.000000  0.793469  0.853794  0.287202
# Value   0.793469  1.000000  0.982940  0.332562
# Score   0.853794  0.982940  1.000000  0.341863
# Deaths  0.287202  0.332562  0.341863  1.000000

# %%
healthstatus_data = health.loc[health['Measure Name'] ==  'High Health Status',]
print(healthstatus_data.head())

healthstatus_corr = healthstatus_data[['Rank','Value','Score','Deaths']].corr()
print(healthstatus_corr)
# Out:
#             Measure Name       State  Rank  Value  Score        Date  Fips  \
# 567   High Health Status      Alaska  20.0   57.8   0.52  2022-10-15     2
# 1575  High Health Status     Alabama  48.0   47.5  -1.74  2022-10-15     1
# 2583  High Health Status    Arkansas  46.0   48.8  -1.46  2022-10-15     5
# 3591  High Health Status     Arizona  32.0   55.1  -0.08  2022-10-15     4
# 4599  High Health Status  California  40.0   53.3  -0.47  2022-10-15     6
#
#          Cases  Deaths
# 567     305705    1350
# 1575   1528739   20505
# 2583    955798   12371
# 3591   2277635   31455
# 4599  11317958   96460
#             Rank     Value     Score    Deaths
# Rank    1.000000 -0.972679 -0.977843  0.266355
# Value  -0.972679  1.000000  0.998826 -0.195074
# Score  -0.977843  0.998826  1.000000 -0.203377
# Deaths  0.266355 -0.195074 -0.203377  1.000000

# %% [markdown]
# Hypothesis Testing

# %%
#plots deaths per month for United States as whole
x = air_vs_deaths2['Month_year']
y = air_vs_deaths2['deaths_permonth']

fig, ax = plt.subplots()
ax.plot(x,y)
plt.xticks(rotation=90)
plt.xlabel('Month and Year',fontsize=20,fontname='Times New Roman')
plt.ylabel('Deaths',fontsize=20,fontname='Times New Roman')
plt.title('COVID-19 Deaths Total in United States from 2020-2022',fontsize=25,fontname='Times New Roman')
fig.set_size_inches(18.5, 10.5)

plt.show()

# %%
#Extract total deaths in US per day for before and after event period
df2 = pd.read_csv('all_deaths_day.csv', index_col=[0])

# %%
df2 = df2.groupby(['date'])['deaths_perday'].sum().reset_index()

# %%
#Get total United States deaths per day of 2 months leading up to Christmas 2020/2021 and 2 months after. 
#Create new dataframe with this information and run ANOVA

#Hypothesis: Holidays led to higher prevalence of COVID-19

mask_1 = (df2['date'] >= '2020-11-01') & (df2['date'] <= '2020-12-01')
before_20 = df2.loc[mask_1]
#print(before_20)

mask_2 = (df2['date'] >= '2021-01-01') & (df2['date'] <= '2021-02-01')
after_21 = df2.loc[mask_2]
#print(after_21)

mask_3 = (df2['date'] >= '2021-11-01') & (df2['date'] <= '2021-12-01')
before_21 = df2.loc[mask_3]
#print(before_21)

mask_4 = (df2['date'] >= '2022-01-01') & (df2['date'] <= '2022-02-01')
after_22 = df2.loc[mask_4]
#print(after_22)

# %%
df = pd.concat([before_20,after_21,before_21,after_21])

df_melt = pd.melt(df.reset_index(), id_vars=['date'], value_vars=['deaths_perday'])
df_melt['date'] = pd.to_datetime(df_melt['date'])
df_melt.columns = ['date', 'Variable', 'Deaths_PerDay']
print(df_melt)
# Out:
#           date       Variable  Deaths_PerDay
# 0   2020-11-01  deaths_perday          418.0
# 1   2020-11-02  deaths_perday          532.0
# 2   2020-11-03  deaths_perday         1125.0
# 3   2020-11-04  deaths_perday         1604.0
# 4   2020-11-05  deaths_perday         1100.0
# ..         ...            ...            ...
# 121 2021-01-28  deaths_perday         3854.0
# 122 2021-01-29  deaths_perday         3584.0
# 123 2021-01-30  deaths_perday         2628.0
# 124 2021-01-31  deaths_perday         1854.0
# 125 2021-02-01  deaths_perday         1940.0
#
# [126 rows x 3 columns]

# %%
df_melt['month'] = df_melt['date'].dt.strftime('%b')

# %%
fig, ax = plt.subplots()

ax = sns.boxplot(x='month',y='Deaths_PerDay',data=df_melt,ax=ax)
plt.xlabel('Month',fontsize=12,fontname='Times New Roman')
plt.ylabel('Deaths Per Day',fontsize=12,fontname='Times New Roman')
plt.title('Months vs. Deaths Per Day',fontsize=15, fontname='Times New Roman')

fig.set_size_inches((12,4))
plt.show()

# %% [markdown]
# Null hypothesis: The prevalence of COVID-19 deaths is not affected by the holiday season.

# %%
import scipy.stats as stats

#run ANOVA on dates before and after Christmas 2020
df_anova = df_melt[['Deaths_PerDay']]
fvalue, pvalue = stats.f_oneway(df_anova.iloc[[0,1]], df_anova.iloc[[2,3]])
print(fvalue, pvalue)

#run ANOVA on dates before and after Christmas 2021
fvalue2, pvalue2 = stats.f_oneway(df_anova.iloc[[4,5]], df_anova.iloc[[6,7]])
print(fvalue2, pvalue2)
# Out:
# [13.05428214] [0.06879249]
# [2.38099311] [0.26278734]
